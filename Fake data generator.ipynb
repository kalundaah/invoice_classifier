# %% [markdown]
# # USAGE OF FAKER

# %% [markdown]
# ## Dependencies

# %%
import random
from faker import Faker
faker = Faker()

# %% [markdown]
# fake.

# %%
def randomizer(name,make,make2,choice,choice2,street,city,state,zipcode,word,word2,balance):
    choic = random.choice(["Laptop", "Smartphone", "Tablet", "Monitor", "Keyboard"])
    choic2 = random.choice(["Headphones", "Mouse", "Printer", "Scanner", "Webcam"])
    mak = random.choice(["X1", "S3", "T5", "M2", "K4"])
    mak2= random.choice(["H6", "M3", "P2", "S4", "W1"])
    nam = faker.name()
    stree = faker.street_address()
    cit = faker.city()
    stat = faker.state()
    zipcod = faker.zipcode()
    wor = faker.word()
    wor2 = faker.word()
    balanc = random.uniform(100, 2000)
    choice = choic
    choice2 = choic2
    make = mak
    make2 = mak2
    name = nam
    street = stree
    city = cit
    state = stat
    zipcode = zipcod
    word = wor
    word2 = wor2
    balance = balanc
    return(str("Randomly generated"))

# %%
# # Initialize empty variables
# name= ""
# make= ""
# make2= ""
# choice= ""
# choice2= ""
# street= ""
# city= ""
# state= ""
# zipcode = ""
# word = ""
# word2 = ""
# balance = 0

# # Initialize empty lists to store mock data and labels
# mock = []
# mock_labels = []

# # Generate and store 100 mock invoices
# for _ in range(100):

#     randomizer(name,make,make2,choice,choice2,street,city,state,zipcode,word,word2,balance)

#     invoice_text = f"""
#     Dear Customer,

#     Invoice Number: INV-2023-{random.randint(100, 999)}
#     Invoice Date: 2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}
#     Due Date: 2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}

#     Billing Information:
#     Recipient Name: {name}
#     Recipient Address: {street}, {city}, {state} {zipcode}

#     Product Details:
#     - Description: {word} {choice} {make}
#       Quantity: {random.randint(1, 5)}
#       Unit Price: ${random.uniform(50, 1000):.2f}
#     - Description: {word2} {choice2} {make2}
#       Quantity: {random.randint(1, 5)}
#       Unit Price: ${random.uniform(10, 200):.2f}

#     Balance Due: ${balance}

#     Thank you for your business!
#     """

#     # Append the generated invoice text to the mock list
#     mock.append(invoice_text)

#     # Generate and store the corresponding labels
#     mock_labels.append({
#         "Recipient Name": name,
#         "Recipient Address": f"{street}, {city}, {state} {zipcode}",
#         "Invoice Number": f"INV-2023-{random.randint(100, 999)}",
#         "Invoice Date": f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}",
#         "Due Date": f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}",
#         "Goods Sold": [
#             {
#                 "Description": f"{word} {choice} {make}",
#                 "Quantity": random.randint(1, 5),
#                 "Unit Price": f"${random.uniform(50, 1000):.2f}"
#             },
#             {
#                 "Description": f"{word2} {choice2} {make2}",
#                 "Quantity": random.randint(1, 5),
#                 "Unit Price": f"${random.uniform(10, 200):.2f}"
#             }
#         ],
#         "Balance": f"${balance}"
#     })

# # Print the first mock invoice and its labels for reference
# print(mock[0])
# print(mock_labels[0])

# %%
name = faker.name()
street = faker.street_address()
city = faker.city()
state = faker.state()
zip = faker.zipcode()
word1 = faker.word()

# %%
# Initialize empty lists to store mock data and labels
mock = []
mock_labels = []

# Generate and store 30 mock invoices
for _ in range(30):
    name = faker.name()
    street = faker.street_address()
    city = faker.city()
    state = faker.state()
    zip = faker.zipcode()
    word1 = faker.word()
    choice1 = random.choice(["Laptop", "Smartphone", "Tablet", "Monitor", "Keyboard"])
    make1= random.choice(["X1", "S3", "T5", "M2", "K4"])
    word2 = faker.word()
    choice2 = random.choice(["Headphones", "Mouse", "Printer", "Scanner", "Webcam"])
    make2=random.choice(["H6", "M3", "P2", "S4", "W1"])
    invnos = random.randint(100, 999)
    invmonth =  random.randint(1, 12)
    invday = random.randint(1, 28)
    duemonth =  random.randint(1, 12)
    dueday = random.randint(1, 28)
    balance = random.uniform(100, 999999999)
    invoice_text = f"""
    Dear Customer,

    Invoice Number: INV-2023-{invnos}
    Invoice Date: 2023-{invmonth}-{invday}
    Due Date: 2023-{duemonth}-{dueday}

    Billing Information:
    Recipient Name: {name}
    Recipient Address: {street}, {city}, {state} {zip}

    Product Details:
    - Description: {word1} {choice1} {make1}
      Quantity: {random.randint(1, 5)}
      Unit Price: ${random.uniform(50, 1000):.2f}
    - Description: {word2} {choice2} {make2}
      Quantity: {random.randint(1, 5)}
      Unit Price: ${random.uniform(10, 200):.2f}

    Balance Due: ${balance}

    Thank you for your business!
    """

    # Append the generated invoice text to the mock list
    mock.append(invoice_text)

    # Generate and store the corresponding labels
    mock_labels.append({
        "Recipient Name": name,
        "Recipient Address": f"{street}, {city}, {state} {zip}",
        "Invoice Number": f"INV-2023-{invnos}",
        "Invoice Date": f"2023-{invmonth}-{invday}",
        "Due Date": f"2023-{duemonth}-{dueday}",
        "Balance": f"${balance}"
    })

# Print the first mock invoice and its labels for reference
print(mock[0])
print(mock_labels[0])
# Out:
#     Dear Customer,
#
#     Invoice Number: INV-2023-754
#     Invoice Date: 2023-12-13
#     Due Date: 2023-12-16
#
#     Billing Information:
#     Recipient Name: Ashley Gonzalez
#     Recipient Address: 232 Erin Circles, North Jeffrey, South Dakota 46445
#
#     Product Details:
#     - Description: decide Laptop X1
#       Quantity: 2
#       Unit Price: $677.64
#     - Description: front Webcam W1
#       Quantity: 2
#       Unit Price: $53.94
#
#     Balance Due: $526511028.1326053
#
#     Thank you for your business!
#
# {'Recipient Name': 'Ashley Gonzalez', 'Recipient Address': '232 Erin Circles, North Jeffrey, South Dakota 46445', 'Invoice Number': 'INV-2023-754', 'Invoice Date': '2023-12-13', 'Due Date': '2023-12-16', 'Balance': '$526511028.1326053'}
